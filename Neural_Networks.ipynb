# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
from torchvision.datasets import MNIST
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data preparation

# %% [markdown]
# ### 1.1. Read data from file

# %%
#load the datasets (train data and test data which are pre-splitted)
data1 = MNIST(root='MNIST_dataset', train=True, download=True)
data2 = MNIST(root='MNIST_dataset', train=False, download=True)

#concatenate the data and labels from train and test datasets
all_images = torch.cat((data1.data, data2.data), dim=0)
all_labels = torch.cat((data1.targets, data2.targets), dim=0)

# %% [markdown]
# Now, we have 70,000 images intotal.

# %%
x = all_images.numpy()
y = all_labels.numpy()

print("Total images:", x.shape[0])
# Out:
# Total images: 70000

# %% [markdown]
# ### 1.2. Normalizing the data

# %%
x = x / 255.0  # Normalize pixel values to [0, 1] range

print("min pixel value:", x.min(), ", max pixel value:", x.max())
# Out:
# min pixel value: 0.0 , max pixel value: 1.0

# %% [markdown]
# ### 1.3. Splitting into train, validtaion and test sets

# %%
x_train, x_rest, y_train, y_rest = train_test_split(x, y, train_size= 0.6, random_state=42, stratify=y) # 60% train, 40% to split again into val and test
x_val, x_test, y_val, y_test = train_test_split(x_rest, y_rest, train_size=0.5, random_state=42, stratify=y_rest) # 40% * 50% = 20% val, 20% test

print("Training set = ", x_train.shape[0])
print("Validation set = ", x_val.shape[0])
print("Test set = ", x_test.shape[0])
# Out:
# Training set =  42000
# Validation set =  14000
# Test set =  14000

# %% [markdown]
# ### 1.4. Pytorch DataLoaders

# %%
# change from numpy arrays to tensors
x_train_tensor = torch.from_numpy(x_train).unsqueeze(1).float()
y_train_tensor = torch.from_numpy(y_train).long()

x_val_tensor = torch.from_numpy(x_val).unsqueeze(1).float()
y_val_tensor = torch.from_numpy(y_val).long()

x_test_tensor = torch.from_numpy(x_test).unsqueeze(1).float()
y_test_tensor = torch.from_numpy(y_test).long()

train_dataset = torch.utils.data.TensorDataset(x_train_tensor, y_train_tensor)
val_dataset = torch.utils.data.TensorDataset(x_val_tensor, y_val_tensor)
test_dataset = torch.utils.data.TensorDataset(x_test_tensor, y_test_tensor)

# Create DataLoaders with batch size = 64 to optimize training
train_NN_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_NN_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_NN_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # 2. Neural Network model
# ### 2.1. Feed Forward NN

# %%
class FeedForwardNN(nn.Module):
    def __init__(self, input_size, number_hidden_layers, hidden_size, output_size):
        super(FeedForwardNN, self).__init__()
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(input_size, hidden_size)) 
        for i in range(number_hidden_layers-1):
            self.layers.append(nn.Linear(hidden_size, hidden_size)) 
        self.layers.append(nn.Linear(hidden_size, output_size)) 

        self.weight_initialization()

    def weight_initialization(self):
        # He initialization
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, nonlinearity= 'relu')
                
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
   
    def forward(self, x):
        
        x = x.view(x.size(0), -1) # flatten input (28x28 to 784)
        
        for layer in self.layers[:-1]:
            x = F.relu(layer(x))
        
        x = self.layers[-1](x)

        return x

# %% [markdown]
# ### 2.2. Training the NN model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # for gpu acceleration
print(f"Using {device}") #check if gpu acceleration is working

INPUT_SIZE = 784
NUMBER_HIDDEN_LAYERS = 2
HIDDEN_SIZE = 64
OUTPUT_SIZE = 10 

LEARNING_RATE = 0.01
NUM_EPOCHS = 100

training_losses = []
training_accurices = []
validation_losses = []
validation_accurices = []

model = FeedForwardNN(INPUT_SIZE, NUMBER_HIDDEN_LAYERS, HIDDEN_SIZE, OUTPUT_SIZE).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)
loss_function = nn.CrossEntropyLoss()

num_total_steps = len(train_NN_loader)
for epoch in range(NUM_EPOCHS):
    
    # training loop
    model.train()
    current_train_loss = 0
    total = 0
    correct = 0

    for i, (image, label) in enumerate(train_NN_loader):
        image = image.to(device)
        label = label.to(device)

        #forward
        outputs = model(image)
        loss = loss_function(outputs, label)
        current_train_loss += loss.item()

        #bacward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total += label.size(0)
        correct += (predicted == label).sum().item()

    average_train_loss = current_train_loss / len(train_NN_loader)
    train_accuracy = 100 * correct / total

    training_losses.append(average_train_loss)
    training_accurices.append(train_accuracy)

    #validation loop
    model.eval()
    current_val_loss = 0
    total = 0
    correct = 0

    with torch.no_grad():
        for i, (image, label) in enumerate(val_NN_loader):
            image = image.to(device)
            label = label.to(device)

            #forward
            outputs = model(image)
            loss = loss_function(outputs, label)
            current_val_loss += loss.item()

            #calc accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += label.size(0)
            correct += (predicted == label).sum().item()
    #calculate average validation loss and accuracy
    average_val_loss = current_val_loss / len(val_NN_loader)
    validation_accuracy = 100 * correct / total

    validation_losses.append(average_val_loss)
    validation_accurices.append(validation_accuracy)
    print(f"Epoch: {epoch+1} / {NUM_EPOCHS} | avg train loss: {average_train_loss:.4f} | train accuracy : {train_accuracy:.2f}|avg validation loss: {average_val_loss:.4f} | validation accuracy: {validation_accuracy:.2f} ")
# Out:
# Using cpu
# Epoch: 1 / 100 | avg train loss: 0.9857 | train accuracy : 73.40|avg validation loss: 0.4879 | validation accuracy: 87.22
# Epoch: 2 / 100 | avg train loss: 0.4074 | train accuracy : 88.85|avg validation loss: 0.3814 | validation accuracy: 89.21
# Epoch: 3 / 100 | avg train loss: 0.3349 | train accuracy : 90.52|avg validation loss: 0.3282 | validation accuracy: 90.74
# Epoch: 4 / 100 | avg train loss: 0.2996 | train accuracy : 91.57|avg validation loss: 0.3045 | validation accuracy: 91.13
# Epoch: 5 / 100 | avg train loss: 0.2750 | train accuracy : 92.21|avg validation loss: 0.2851 | validation accuracy: 91.92
# Epoch: 6 / 100 | avg train loss: 0.2566 | train accuracy : 92.73|avg validation loss: 0.2719 | validation accuracy: 92.26
# Epoch: 7 / 100 | avg train loss: 0.2411 | train accuracy : 93.23|avg validation loss: 0.2589 | validation accuracy: 92.64
# Epoch: 8 / 100 | avg train loss: 0.2268 | train accuracy : 93.56|avg validation loss: 0.2439 | validation accuracy: 92.96
# Epoch: 9 / 100 | avg train loss: 0.2153 | train accuracy : 93.97|avg validation loss: 0.2447 | validation accuracy: 92.82
# Epoch: 10 / 100 | avg train loss: 0.2045 | train accuracy : 94.24|avg validation loss: 0.2290 | validation accuracy: 93.53
# Epoch: 11 / 100 | avg train loss: 0.1952 | train accuracy : 94.47|avg validation loss: 0.2203 | validation accuracy: 93.67
# Epoch: 12 / 100 | avg train loss: 0.1863 | train accuracy : 94.74|avg validation loss: 0.2141 | validation accuracy: 93.81
# Epoch: 13 / 100 | avg train loss: 0.1791 | train accuracy : 94.91|avg validation loss: 0.2203 | validation accuracy: 93.79
# Epoch: 14 / 100 | avg train loss: 0.1718 | train accuracy : 95.12|avg validation loss: 0.1999 | validation accuracy: 94.36
# Epoch: 15 / 100 | avg train loss: 0.1650 | train accuracy : 95.32|avg validation loss: 0.1951 | validation accuracy: 94.39
# Epoch: 16 / 100 | avg train loss: 0.1589 | train accuracy : 95.48|avg validation loss: 0.1886 | validation accuracy: 94.52
# Epoch: 17 / 100 | avg train loss: 0.1529 | train accuracy : 95.65|avg validation loss: 0.1840 | validation accuracy: 94.71
# Epoch: 18 / 100 | avg train loss: 0.1478 | train accuracy : 95.77|avg validation loss: 0.1806 | validation accuracy: 94.79
# Epoch: 19 / 100 | avg train loss: 0.1429 | train accuracy : 95.95|avg validation loss: 0.1774 | validation accuracy: 94.88
# Epoch: 20 / 100 | avg train loss: 0.1382 | train accuracy : 95.98|avg validation loss: 0.1734 | validation accuracy: 94.99
# Epoch: 21 / 100 | avg train loss: 0.1336 | train accuracy : 96.23|avg validation loss: 0.1685 | validation accuracy: 95.19
# Epoch: 22 / 100 | avg train loss: 0.1295 | train accuracy : 96.33|avg validation loss: 0.1667 | validation accuracy: 95.11
# Epoch: 23 / 100 | avg train loss: 0.1254 | train accuracy : 96.41|avg validation loss: 0.1628 | validation accuracy: 95.21
# Epoch: 24 / 100 | avg train loss: 0.1220 | train accuracy : 96.54|avg validation loss: 0.1587 | validation accuracy: 95.45
# Epoch: 25 / 100 | avg train loss: 0.1182 | train accuracy : 96.72|avg validation loss: 0.1574 | validation accuracy: 95.51
# Epoch: 26 / 100 | avg train loss: 0.1147 | train accuracy : 96.81|avg validation loss: 0.1554 | validation accuracy: 95.56
# Epoch: 27 / 100 | avg train loss: 0.1113 | train accuracy : 96.88|avg validation loss: 0.1556 | validation accuracy: 95.44
# Epoch: 28 / 100 | avg train loss: 0.1084 | train accuracy : 96.97|avg validation loss: 0.1515 | validation accuracy: 95.57
# Epoch: 29 / 100 | avg train loss: 0.1053 | train accuracy : 97.07|avg validation loss: 0.1509 | validation accuracy: 95.61
# Epoch: 30 / 100 | avg train loss: 0.1024 | train accuracy : 97.17|avg validation loss: 0.1453 | validation accuracy: 95.81
# Epoch: 31 / 100 | avg train loss: 0.0993 | train accuracy : 97.21|avg validation loss: 0.1458 | validation accuracy: 95.70
# Epoch: 32 / 100 | avg train loss: 0.0971 | train accuracy : 97.28|avg validation loss: 0.1444 | validation accuracy: 95.74
# Epoch: 33 / 100 | avg train loss: 0.0947 | train accuracy : 97.38|avg validation loss: 0.1415 | validation accuracy: 95.77
# Epoch: 34 / 100 | avg train loss: 0.0921 | train accuracy : 97.43|avg validation loss: 0.1399 | validation accuracy: 95.92
# Epoch: 35 / 100 | avg train loss: 0.0898 | train accuracy : 97.52|avg validation loss: 0.1417 | validation accuracy: 95.74
# Epoch: 36 / 100 | avg train loss: 0.0879 | train accuracy : 97.55|avg validation loss: 0.1386 | validation accuracy: 95.83
# Epoch: 37 / 100 | avg train loss: 0.0856 | train accuracy : 97.62|avg validation loss: 0.1363 | validation accuracy: 95.97
# Epoch: 38 / 100 | avg train loss: 0.0835 | train accuracy : 97.67|avg validation loss: 0.1341 | validation accuracy: 96.04
# Epoch: 39 / 100 | avg train loss: 0.0813 | train accuracy : 97.79|avg validation loss: 0.1331 | validation accuracy: 96.18
# Epoch: 40 / 100 | avg train loss: 0.0796 | train accuracy : 97.80|avg validation loss: 0.1323 | validation accuracy: 96.22
# Epoch: 41 / 100 | avg train loss: 0.0778 | train accuracy : 97.84|avg validation loss: 0.1334 | validation accuracy: 96.02
# Epoch: 42 / 100 | avg train loss: 0.0761 | train accuracy : 97.96|avg validation loss: 0.1350 | validation accuracy: 95.96
# Epoch: 43 / 100 | avg train loss: 0.0743 | train accuracy : 97.97|avg validation loss: 0.1296 | validation accuracy: 96.22
# Epoch: 44 / 100 | avg train loss: 0.0727 | train accuracy : 97.97|avg validation loss: 0.1281 | validation accuracy: 96.23
# Epoch: 45 / 100 | avg train loss: 0.0711 | train accuracy : 98.05|avg validation loss: 0.1269 | validation accuracy: 96.21
# Epoch: 46 / 100 | avg train loss: 0.0694 | train accuracy : 98.11|avg validation loss: 0.1273 | validation accuracy: 96.39
# Epoch: 47 / 100 | avg train loss: 0.0681 | train accuracy : 98.16|avg validation loss: 0.1258 | validation accuracy: 96.22
# Epoch: 48 / 100 | avg train loss: 0.0663 | train accuracy : 98.23|avg validation loss: 0.1248 | validation accuracy: 96.31
# Epoch: 49 / 100 | avg train loss: 0.0651 | train accuracy : 98.24|avg validation loss: 0.1255 | validation accuracy: 96.29
# Epoch: 50 / 100 | avg train loss: 0.0637 | train accuracy : 98.29|avg validation loss: 0.1238 | validation accuracy: 96.33
# Epoch: 51 / 100 | avg train loss: 0.0626 | train accuracy : 98.32|avg validation loss: 0.1232 | validation accuracy: 96.29
# Epoch: 52 / 100 | avg train loss: 0.0610 | train accuracy : 98.37|avg validation loss: 0.1232 | validation accuracy: 96.33
# Epoch: 53 / 100 | avg train loss: 0.0600 | train accuracy : 98.40|avg validation loss: 0.1277 | validation accuracy: 96.23
# Epoch: 54 / 100 | avg train loss: 0.0588 | train accuracy : 98.45|avg validation loss: 0.1220 | validation accuracy: 96.39
# Epoch: 55 / 100 | avg train loss: 0.0578 | train accuracy : 98.42|avg validation loss: 0.1214 | validation accuracy: 96.34
# Epoch: 56 / 100 | avg train loss: 0.0564 | train accuracy : 98.52|avg validation loss: 0.1198 | validation accuracy: 96.50
# Epoch: 57 / 100 | avg train loss: 0.0551 | train accuracy : 98.55|avg validation loss: 0.1222 | validation accuracy: 96.39
# Epoch: 58 / 100 | avg train loss: 0.0541 | train accuracy : 98.56|avg validation loss: 0.1201 | validation accuracy: 96.50
# Epoch: 59 / 100 | avg train loss: 0.0530 | train accuracy : 98.60|avg validation loss: 0.1206 | validation accuracy: 96.39
# Epoch: 60 / 100 | avg train loss: 0.0524 | train accuracy : 98.63|avg validation loss: 0.1212 | validation accuracy: 96.50
# Epoch: 61 / 100 | avg train loss: 0.0510 | train accuracy : 98.65|avg validation loss: 0.1203 | validation accuracy: 96.52
# Epoch: 62 / 100 | avg train loss: 0.0502 | train accuracy : 98.68|avg validation loss: 0.1179 | validation accuracy: 96.61
# Epoch: 63 / 100 | avg train loss: 0.0491 | train accuracy : 98.71|avg validation loss: 0.1189 | validation accuracy: 96.50
# Epoch: 64 / 100 | avg train loss: 0.0483 | train accuracy : 98.73|avg validation loss: 0.1205 | validation accuracy: 96.57
# Epoch: 65 / 100 | avg train loss: 0.0473 | train accuracy : 98.80|avg validation loss: 0.1185 | validation accuracy: 96.51
# Epoch: 66 / 100 | avg train loss: 0.0463 | train accuracy : 98.80|avg validation loss: 0.1183 | validation accuracy: 96.54
# Epoch: 67 / 100 | avg train loss: 0.0453 | train accuracy : 98.84|avg validation loss: 0.1192 | validation accuracy: 96.54
# Epoch: 68 / 100 | avg train loss: 0.0445 | train accuracy : 98.90|avg validation loss: 0.1190 | validation accuracy: 96.51
# Epoch: 69 / 100 | avg train loss: 0.0437 | train accuracy : 98.92|avg validation loss: 0.1177 | validation accuracy: 96.61
# Epoch: 70 / 100 | avg train loss: 0.0429 | train accuracy : 98.88|avg validation loss: 0.1183 | validation accuracy: 96.62
# Epoch: 71 / 100 | avg train loss: 0.0420 | train accuracy : 98.91|avg validation loss: 0.1183 | validation accuracy: 96.59
# Epoch: 72 / 100 | avg train loss: 0.0413 | train accuracy : 98.99|avg validation loss: 0.1172 | validation accuracy: 96.66
# Epoch: 73 / 100 | avg train loss: 0.0405 | train accuracy : 99.01|avg validation loss: 0.1165 | validation accuracy: 96.66
# Epoch: 74 / 100 | avg train loss: 0.0398 | train accuracy : 99.01|avg validation loss: 0.1198 | validation accuracy: 96.46
# Epoch: 75 / 100 | avg train loss: 0.0389 | train accuracy : 99.06|avg validation loss: 0.1188 | validation accuracy: 96.60
# Epoch: 76 / 100 | avg train loss: 0.0381 | train accuracy : 99.05|avg validation loss: 0.1171 | validation accuracy: 96.62
# Epoch: 77 / 100 | avg train loss: 0.0380 | train accuracy : 99.08|avg validation loss: 0.1182 | validation accuracy: 96.67
# Epoch: 78 / 100 | avg train loss: 0.0368 | train accuracy : 99.11|avg validation loss: 0.1213 | validation accuracy: 96.59
# Epoch: 79 / 100 | avg train loss: 0.0363 | train accuracy : 99.12|avg validation loss: 0.1173 | validation accuracy: 96.69
# Epoch: 80 / 100 | avg train loss: 0.0356 | train accuracy : 99.15|avg validation loss: 0.1191 | validation accuracy: 96.53
# Epoch: 81 / 100 | avg train loss: 0.0349 | train accuracy : 99.18|avg validation loss: 0.1162 | validation accuracy: 96.61
# Epoch: 82 / 100 | avg train loss: 0.0342 | train accuracy : 99.20|avg validation loss: 0.1158 | validation accuracy: 96.72
# Epoch: 83 / 100 | avg train loss: 0.0336 | train accuracy : 99.21|avg validation loss: 0.1168 | validation accuracy: 96.71
# Epoch: 84 / 100 | avg train loss: 0.0328 | train accuracy : 99.22|avg validation loss: 0.1171 | validation accuracy: 96.69
# Epoch: 85 / 100 | avg train loss: 0.0321 | train accuracy : 99.26|avg validation loss: 0.1174 | validation accuracy: 96.71
# Epoch: 86 / 100 | avg train loss: 0.0317 | train accuracy : 99.25|avg validation loss: 0.1170 | validation accuracy: 96.62
# Epoch: 87 / 100 | avg train loss: 0.0312 | train accuracy : 99.30|avg validation loss: 0.1193 | validation accuracy: 96.59
# Epoch: 88 / 100 | avg train loss: 0.0307 | train accuracy : 99.30|avg validation loss: 0.1202 | validation accuracy: 96.68
# Epoch: 89 / 100 | avg train loss: 0.0300 | train accuracy : 99.37|avg validation loss: 0.1188 | validation accuracy: 96.62
# Epoch: 90 / 100 | avg train loss: 0.0296 | train accuracy : 99.34|avg validation loss: 0.1174 | validation accuracy: 96.69
# Epoch: 91 / 100 | avg train loss: 0.0290 | train accuracy : 99.36|avg validation loss: 0.1173 | validation accuracy: 96.69
# Epoch: 92 / 100 | avg train loss: 0.0283 | train accuracy : 99.38|avg validation loss: 0.1183 | validation accuracy: 96.64
# Epoch: 93 / 100 | avg train loss: 0.0278 | train accuracy : 99.39|avg validation loss: 0.1193 | validation accuracy: 96.67
# Epoch: 94 / 100 | avg train loss: 0.0274 | train accuracy : 99.43|avg validation loss: 0.1187 | validation accuracy: 96.64
# Epoch: 95 / 100 | avg train loss: 0.0268 | train accuracy : 99.43|avg validation loss: 0.1184 | validation accuracy: 96.63
# Epoch: 96 / 100 | avg train loss: 0.0263 | train accuracy : 99.47|avg validation loss: 0.1170 | validation accuracy: 96.65
# Epoch: 97 / 100 | avg train loss: 0.0257 | train accuracy : 99.49|avg validation loss: 0.1182 | validation accuracy: 96.71
# Epoch: 98 / 100 | avg train loss: 0.0255 | train accuracy : 99.48|avg validation loss: 0.1186 | validation accuracy: 96.72
# Epoch: 99 / 100 | avg train loss: 0.0249 | train accuracy : 99.52|avg validation loss: 0.1187 | validation accuracy: 96.66
# Epoch: 100 / 100 | avg train loss: 0.0245 | train accuracy : 99.51|avg validation loss: 0.1191 | validation accuracy: 96.65

# %% [markdown]
# ### 2.3 Training VS Validation plots
